# %%
import numpy as np

# %%
data = [50,50,47,97,49,3,53,42,26,74,82,62,37,15,70,27,36,35,48,52,63,64]

grades = np.array(data)

# %%
horas_estudio = [10.0,11.5,9.0,16.0,9.25,1.0,11.5,9.0,8.5,14.5,15.5,
               13.75,9.0,8.0,15.5,8.0,9.0,6.0,10.0,12.0,12.5,12.0]

# Creaci'on de un arreglo 2D 
data_estudiantes = np.array([horas_estudio, grades])

# Muestra
data_estudiantes
# Out:
# array([[10.  , 11.5 ,  9.  , 16.  ,  9.25,  1.  , 11.5 ,  9.  ,  8.5 ,
#         14.5 , 15.5 , 13.75,  9.  ,  8.  , 15.5 ,  8.  ,  9.  ,  6.  ,
#         10.  , 12.  , 12.5 , 12.  ],
#        [50.  , 50.  , 47.  , 97.  , 49.  ,  3.  , 53.  , 42.  , 26.  ,
#         74.  , 82.  , 62.  , 37.  , 15.  , 70.  , 27.  , 36.  , 35.  ,
#         48.  , 52.  , 63.  , 64.  ]])

# %%
data_estudiantes.shape
# Out:
# (2, 22)

# %%
# Muesta el primer elemento del primer arreglo
data_estudiantes[0][0]
# Out:
# 10.0

# %%
# Comparando las horas de estudio con la calificai'on del estudiante
# calcular la media de cada sub array

avg_estudiantes = data_estudiantes[0].mean()
avg_grades = data_estudiantes[1].mean()

print('El promedio de las horas estudiadas es: {:.2f}, el promdedio de las notas es: {:.2f}'.format(avg_estudiantes, avg_grades))
# Out:
# El promedio de las horas estudiadas es: 10.52, el promdedio de las notas es: 49.18

# %% [markdown]
# ### Tabular data pandas

# %%
import pandas as pd

# %%
df_students = pd.DataFrame({'Name': ['Dan', 'Joann', 'Pedro', 'Rosie', 'Ethan', 'Vicky', 'Frederic', 'Jimmie', 
                                     'Rhonda', 'Giovanni', 'Francesca', 'Rajab', 'Naiyana', 'Kian', 'Jenny',
                                     'Jakeem','Helena','Ismat','Anila','Skye','Daniel','Aisha'],
                            'StudyHours':data_estudiantes[0],
                            'Grade':data_estudiantes[1]})

# %%
df_students
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0

# %%
# Datos de indice 5
df_students.loc[5]
# Out:
# Name          Vicky
# StudyHours      1.0
# Grade           3.0
# Name: 5, dtype: object

# %%
# Del 0 al 5
df_students.loc[:5]
# Out:
#     Name  StudyHours  Grade
# 0    Dan       10.00   50.0
# 1  Joann       11.50   50.0
# 2  Pedro        9.00   47.0
# 3  Rosie       16.00   97.0
# 4  Ethan        9.25   49.0
# 5  Vicky        1.00    3.0

# %%
df_students.iloc[0:5]
# Out:
#     Name  StudyHours  Grade
# 0    Dan       10.00   50.0
# 1  Joann       11.50   50.0
# 2  Pedro        9.00   47.0
# 3  Rosie       16.00   97.0
# 4  Ethan        9.25   49.0

# %%
# Acceder a los datos por posici'on
df_students.iloc[0,[2]]
# Out:
# Grade    50.0
# Name: 0, dtype: object

# %%
df_students.loc[0, 'Grade']
# Out:
# 50.0

# %%
# Expresion de filtrado
df_students[df_students['Name']=='Aisha']
# Out:
#      Name  StudyHours  Grade
# 21  Aisha        12.0   64.0

# %%
df_students.loc[df_students["Name"]=='Aisha']
# Out:
#      Name  StudyHours  Grade
# 21  Aisha        12.0   64.0

# %%
# Metodo query
df_students.query('Name=="Aisha"')
# Out:
#      Name  StudyHours  Grade
# 21  Aisha        12.0   64.0

# %%
# Haciendo referencia al nombre de la columna
df_students[df_students.Name == 'Aisha']
# Out:
#      Name  StudyHours  Grade
# 21  Aisha        12.0   64.0

# %%
df_students = pd.read_csv('grades.csv',delimiter=',',header='infer')
df_students.head()
# Out:
#     Name  StudyHours  Grade
# 0    Dan       10.00   50.0
# 1  Joann       11.50   50.0
# 2  Pedro        9.00   47.0
# 3  Rosie       16.00   97.0
# 4  Ethan        9.25   49.0

# %%
# Manejando datos faltantes
df_students.isnull().sum()
# Out:
# Name          0
# StudyHours    1
# Grade         2
# dtype: int64

# %%
# Filtro del data frame para incluir solo los valores nulos
df_students[df_students.isnull().any(axis=1)]
# Out:
#     Name  StudyHours  Grade
# 22  Bill         8.0    NaN
# 23   Ted         NaN    NaN

# %%
# se asume un promedio para estos datos
df_students.StudyHours = df_students.StudyHours.fillna(df_students.StudyHours.mean())
df_students
# Out:
#          Name  StudyHours  Grade
# 0         Dan   10.000000   50.0
# 1       Joann   11.500000   50.0
# 2       Pedro    9.000000   47.0
# 3       Rosie   16.000000   97.0
# 4       Ethan    9.250000   49.0
# 5       Vicky    1.000000    3.0
# 6    Frederic   11.500000   53.0
# 7      Jimmie    9.000000   42.0
# 8      Rhonda    8.500000   26.0
# 9    Giovanni   14.500000   74.0
# 10  Francesca   15.500000   82.0
# 11      Rajab   13.750000   62.0
# 12    Naiyana    9.000000   37.0
# 13       Kian    8.000000   15.0
# 14      Jenny   15.500000   70.0
# 15     Jakeem    8.000000   27.0
# 16     Helena    9.000000   36.0
# 17      Ismat    6.000000   35.0
# 18      Anila   10.000000   48.0
# 19       Skye   12.000000   52.0
# 20     Daniel   12.500000   63.0
# 21      Aisha   12.000000   64.0
# 22       Bill    8.000000    NaN
# 23        Ted   10.413043    NaN

# %%
# dropna
df_students = df_students.dropna(axis=0, how='any')
df_students
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0

# %% [markdown]
# # Explorando los datos

# %%
# calcular la media de las horas de estudio usando el indice de columnas
mean_study = df_students['StudyHours'].mean()

# Calcular la media de las notas usando el nombre de la columna como propiedad
mean_grade = df_students.Grade.mean()

print('Promedio horas estudiadas: {:.2f} \nPromedio notas: {:.2f}'.format(mean_study, mean_grade))
# Out:
# Promedio horas estudiadas: 10.52
# Promedio notas: 49.18

# %% [markdown]
# Filtramos el dataframe para buscar solo los estudiantes que estudiaron m'as del promedio total de horas

# %%
# Mas del promedio de horas

df_students[df_students.StudyHours > mean_study]
# Out:
#          Name  StudyHours  Grade
# 1       Joann       11.50   50.0
# 3       Rosie       16.00   97.0
# 6    Frederic       11.50   53.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 14      Jenny       15.50   70.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0

# %% [markdown]
# Buscamos el promedio de notas para estudiantes que estudianron mas horas que el promedio

# %%
# Cual fue el promedio de notas de los que mas horas estudiaron?
df_students[df_students.StudyHours > mean_study].Grade.mean()
# Out:
# 66.7

# %% [markdown]
# Buscaremos los estudiantes que pasan
# Creamos un serie en pandas que contenga el indicador pass/fail que se concatena con un nueva columna

# %%
passes = pd.Series(df_students['Grade'] > 60)
df_students = pd.concat([df_students, passes.rename("Pass")], axis=1)

df_students
# Out:
#          Name  StudyHours  Grade   Pass
# 0         Dan       10.00   50.0  False
# 1       Joann       11.50   50.0  False
# 2       Pedro        9.00   47.0  False
# 3       Rosie       16.00   97.0   True
# 4       Ethan        9.25   49.0  False
# 5       Vicky        1.00    3.0  False
# 6    Frederic       11.50   53.0  False
# 7      Jimmie        9.00   42.0  False
# 8      Rhonda        8.50   26.0  False
# 9    Giovanni       14.50   74.0   True
# 10  Francesca       15.50   82.0   True
# 11      Rajab       13.75   62.0   True
# 12    Naiyana        9.00   37.0  False
# 13       Kian        8.00   15.0  False
# 14      Jenny       15.50   70.0   True
# 15     Jakeem        8.00   27.0  False
# 16     Helena        9.00   36.0  False
# 17      Ismat        6.00   35.0  False
# 18      Anila       10.00   48.0  False
# 19       Skye       12.00   52.0  False
# 20     Daniel       12.50   63.0   True
# 21      Aisha       12.00   64.0   True

# %%
# uso del metodo groupby
print(df_students.groupby(df_students.Pass).Name.count())
# Out:
# Pass
# False    15
# True      7
# Name: Name, dtype: int64

# %%
# Create a DataFrame with the data sorted by Grade (descending)
df_students = df_students.sort_values('Grade', ascending=False)

# Show the DataFrame
df_students
# Out:
#          Name  StudyHours  Grade   Pass
# 3       Rosie       16.00   97.0   True
# 10  Francesca       15.50   82.0   True
# 9    Giovanni       14.50   74.0   True
# 14      Jenny       15.50   70.0   True
# 21      Aisha       12.00   64.0   True
# 20     Daniel       12.50   63.0   True
# 11      Rajab       13.75   62.0   True
# 6    Frederic       11.50   53.0  False
# 19       Skye       12.00   52.0  False
# 1       Joann       11.50   50.0  False
# 0         Dan       10.00   50.0  False
# 4       Ethan        9.25   49.0  False
# 18      Anila       10.00   48.0  False
# 2       Pedro        9.00   47.0  False
# 7      Jimmie        9.00   42.0  False
# 12    Naiyana        9.00   37.0  False
# 16     Helena        9.00   36.0  False
# 17      Ismat        6.00   35.0  False
# 15     Jakeem        8.00   27.0  False
# 8      Rhonda        8.50   26.0  False
# 13       Kian        8.00   15.0  False
# 5       Vicky        1.00    3.0  False
